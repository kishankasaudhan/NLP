# %% [markdown]
# <a href="https://colab.research.google.com/github/kishankasaudhan/NLP/blob/main/Train_Word2Vec_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#USING PRETRAINED EMBEDDINGS
# 2. popular pretrained model
#1. google news Word2Vec (300)
#2. GloVe (Stanford)
# !pip install gensim
import gensim.downloader as api
print("Loading pretrained models: ")
model = api.load("word2vec-google-news-300")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 69.5 MB/s eta 0:00:00
# ...
# Loading pretrained models:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
