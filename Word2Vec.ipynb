# %% [markdown]
# <a href="https://colab.research.google.com/github/kishankasaudhan/NLP/blob/main/Word2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Word2Vec INTRODUCTION

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.1)

# %%
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sentences = [
    "I am learning natural language processing",
    "Natural Language Processing is part of artificial intelligence",
    "I am also learning machine learning",
    "I also want to learn Deep Learning",
    "Deep Learning uses neural network",
    "Neural networks are powerful"
]

# %%
from nltk.tokenize import word_tokenize
tokenized_sentences = [word_tokenize(s.lower()) for s in sentences]
print(tokenized_sentences)
# Out:
# [['i', 'am', 'learning', 'natural', 'language', 'processing'], ['natural', 'language', 'processing', 'is', 'part', 'of', 'artificial', 'intelligence'], ['i', 'am', 'also', 'learning', 'machine', 'learning'], ['i', 'also', 'want', 'to', 'learn', 'deep', 'learning'], ['deep', 'learning', 'uses', 'neural', 'network'], ['neural', 'networks', 'are', 'powerful']]

# %%
model = Word2Vec(
    sentences = tokenized_sentences,
    vector_size = 100,
    window = 5,
    min_count = 1
)

# %%
print(model.wv.similarity("deep","learning"))
# Out:
# -0.11168033

# %%
print(model.wv.similarity("language","natural"))
# Out:
# 0.004907134

# %%
print(model.wv.similarity("machine","intelligence"))
# Out:
# 0.11937461

# %%
print(model.wv.most_similar("deep"))
# Out:
# [('learn', 0.17826788127422333), ('processing', 0.13149002194404602), ('am', 0.07493316382169724), ('i', 0.06794264912605286), ('language', 0.041521843522787094), ('networks', 0.04129067063331604), ('machine', 0.041218336671590805), ('is', 0.04084636643528938), ('of', 0.03138956055045128), ('are', 0.012966864742338657)]

# %%
print(model.wv.most_similar("deep",topn=5))
# Out:
# [('learn', 0.17826788127422333), ('processing', 0.13149002194404602), ('am', 0.07493316382169724), ('i', 0.06794264912605286), ('language', 0.041521843522787094)]

# %%
# Internally:
# During trainning:
# model slides window across text
# learn weights via neural network
# produces embedding matrix

#Woerd2Vec is:
# a shallow neural network with one hidden layer only

#Limitation of Word2Vec
# Static embeddings (same vector for every context)
# "bank" - money / river
